# %% [markdown]
# ## Quantitative Value Strategy
# ### Obtaining Data

# %%
# !pip install yahoo_fin
# !pip install xlsxwriter
# Out:
# Requirement already satisfied: yahoo_fin in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (0.8.9.1)
# Requirement already satisfied: requests-html in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: requests in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from yahoo_fin) (2.31.0)
# Requirement already satisfied: pandas in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from yahoo_fin) (2.0.3)
# Requirement already satisfied: sgmllib3k in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pandas->yahoo_fin) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pandas->yahoo_fin) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pandas->yahoo_fin) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests->yahoo_fin) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests->yahoo_fin) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests->yahoo_fin) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests->yahoo_fin) (2022.6.15)
# Requirement already satisfied: pyquery in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: fake-useragent in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests-html->yahoo_fin) (1.2.1)
# Requirement already satisfied: parse in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests-html->yahoo_fin) (1.19.1)
# Requirement already satisfied: bs4 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests-html->yahoo_fin) (2.1.2)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (6.8.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.66.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.4)
# Requirement already satisfied: six>=1.5 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from bs4->requests-html->yahoo_fin) (4.12.2)
# Requirement already satisfied: lxml>=2.1 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pyquery->requests-html->yahoo_fin) (4.9.3)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from pyquery->requests-html->yahoo_fin) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.17.0)
# Requirement already satisfied: colorama in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html->yahoo_fin) (0.4.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.5)
# Requirement already satisfied: xlsxwriter in c:\users\devjy\appdata\local\programs\python\python310\lib\site-packages (3.1.9)

# %%
from yahoo_fin.stock_info import tickers_nasdaq, get_stats_valuation, get_live_price
import pandas as pd
import numpy as np
import math
from scipy import stats
from statistics import mean

# %%
tickers = tickers_nasdaq() #Getting Tickers of all Stocks Listed on Nasdaq
dataset = pd.DataFrame(columns = ["Ticker", "Price/Earnings", "Price/Sales (TTM)", "Price/Book (MRQ)", "Enterprise Value/Revenue",	"Enterprise Value/EBITDA", "Price"])

# %%
for ticker in tickers:
  try:
    data = get_stats_valuation(ticker)
    price = get_live_price(ticker)
    dataset.loc[len(dataset.index)] = [ticker, data[1][5], data[1][4], data[1][6], data[1][7], data[1][8], price]
  except:
    pass

# %%
dataset.isna().sum()

# %%
data = dataset.dropna(subset = ["Ticker", "Price/Earnings", "Price/Sales (TTM)", "Price/Book (MRQ)", "Enterprise Value/Revenue", "Enterprise Value/EBITDA"])
# data

# %%
data.to_csv("Valuation_Measures_Data.csv", index = False)

# %% [markdown]
# ### Analysis

# %%
data = dataset.reindex(columns=[*data.columns.tolist(), 'P/E Percentile', 'P/S Percentile', 'P/B Percentile', 'EV/R Percentile', 'EV/EBITDA Percentile', 'RV Score', "Number of Shares to Buy"], fill_value=0)
data
# Out:
#      Ticker Price/Earnings Price/Sales (TTM) Price/Book (MRQ)  \
# 1      AADI           1.89               6.2             0.98
# 3      AAON          30.74              4.37             6.87
# 4      AAPL          28.85              7.13             44.6
# 5      ABCL          19.92              9.79             1.14
# 6      ABCM          1.85k             11.33             5.92
# ...     ...            ...               ...              ...
# 2352   ZEUS          14.88              0.26             1.09
# 2356     ZI           50.9              5.31              2.7
# 2359   ZJYL          40.27              6.54             5.55
# 2360   ZKIN          11.93              0.21             0.26
# 2362     ZM         145.32              4.64             2.94
#
#      Enterprise Value/Revenue Enterprise Value/EBITDA   Price  P/E Percentile  \
# 1                       -0.23                    0.08    4.84               0
# 3                        4.75                   24.57   56.87               0
# 4                        7.12                   21.56  171.21               0
# 5                        3.58                  -48.93    4.60               0
# 6                       11.33                   69.19   22.63               0
# ...                       ...                     ...     ...             ...
# 2352                     0.37                    9.04   56.21               0
# 2356                     5.83                   17.31   16.40               0
# 2359                     5.95                   36.94   23.40               0
# 2360                     0.33                  -13.97    0.70               0
# 2362                     3.27                   66.32   69.94               0
#
#       P/S Percentile  P/B Percentile  EV/R Percentile  EV/EBITDA Percentile  \
# 1                  0               0                0                     0
# 3                  0               0                0                     0
# 4                  0               0                0                     0
# 5                  0               0                0                     0
# 6                  0               0                0                     0
# ...              ...             ...              ...                   ...
# 2352               0               0                0                     0
# 2356               0               0                0                     0
# 2359               0               0                0                     0
# 2360               0               0                0                     0
# 2362               0               0                0                     0
#
#       RV Score  Number of Shares to Buy
# 1            0                        0
# 3            0                        0
# 4            0                        0
# 5            0                        0
# 6            0                        0
# ...        ...                      ...
# 2352         0                        0
# 2356         0                        0
# 2359         0                        0
# 2360         0                        0
# 2362         0                        0
#
# [1174 rows x 14 columns]

# %% [markdown]
# ### Creating Robust Value Metric

# %%
metrics = {
            'Price/Earnings': 'P/E Percentile',
            'Price/Sales (TTM)': 'P/S Percentile',
            'Price/Book (MRQ)':'P/B Percentile',
            'Enterprise Value/Revenue':'EV/R Percentile',
            'Enterprise Value/EBITDA':'EV/EBITDA Percentile',
}

for row in data.index:
    for metric in metrics.keys():
        data.loc[row, metrics[metric]] = stats.percentileofscore(data[metric], data.loc[row, metric]) / 100

data
# Out:
#      Ticker Price/Earnings Price/Sales (TTM) Price/Book (MRQ)  \
# 1361   MNTK           94.8              7.58             5.98
# 1986   STAA          80.94              6.55             5.55
# 394    CDMO           9.41              4.24             3.31
# 1445   NFLX          40.35              5.33             7.36
# 1427   NBIX          64.42              6.95             6.04
# ...     ...            ...               ...              ...
# 2045   TBLT           0.01              0.03             0.41
# 1451   NISN            0.6              0.05             0.06
# 1220   LIZI           1.23              0.06             0.29
# 1028   IMPP           0.32              0.12             0.12
# 2036   TANH           0.46              0.03             0.04
#
#      Enterprise Value/Revenue Enterprise Value/EBITDA   Price  P/E Percentile  \
# 1361                     7.62                   31.75    9.11       99.148211
# 1986                     5.89                   57.97   40.18       94.463373
# 394                      5.29                   97.26    9.44       97.274276
# 1445                     5.49                    8.66  377.60       70.783646
# 1427                     6.27                    40.8  112.50       85.945486
# ...                       ...                     ...     ...             ...
# 2045                      0.1                   -0.52    0.19        0.212947
# 1451                    -0.23                   -2.18    2.39        2.683135
# 1220                    -0.03                    -0.7    3.86        4.429302
# 1028                    -0.29                   -0.59    1.58        1.703578
# 2036                    -0.09                   -0.69    1.35        2.129472
#
#       P/S Percentile  P/B Percentile  EV/R Percentile  EV/EBITDA Percentile  \
# 1361       94.974446       92.419080        96.337308             68.356048
# 1986       92.589438       89.991482        92.206133             81.005111
# 394        83.304940       75.766610        89.224872             99.744463
# 1445       88.756388       96.592845        90.587734             94.207836
# 1427       93.611584       92.759796        93.441227             73.850085
# ...              ...             ...              ...                   ...
# 2045        0.638842        7.155026         8.177172              2.044293
# 1451        1.320273        0.383305         1.277683              7.921635
# 1220        1.703578        4.003407         0.170358              2.896082
# 1028        4.045997        1.405451         1.448041              2.470187
# 2036        0.638842        0.170358         0.724020              2.810903
#
#       RV Score  Number of Shares to Buy
# 1361  0.902470                        0
# 1986  0.900511                        0
# 394   0.890630                        0
# 1445  0.881857                        0
# 1427  0.879216                        0
# ...        ...                      ...
# 2045  0.036457                        0
# 1451  0.027172                        0
# 1220  0.026405                        0
# 1028  0.022147                        0
# 2036  0.012947                        0
#
# [1174 rows x 14 columns]

# %%
for row in data.index:
    value_percentiles = []
    for metric in metrics.keys():
        value_percentiles.append(data.loc[row, metrics[metric]])
    data.loc[row, 'RV Score'] = mean(value_percentiles)

data
# Out:
#      Ticker Price/Earnings Price/Sales (TTM) Price/Book (MRQ)  \
# 1361   MNTK           94.8              7.58             5.98
# 1986   STAA          80.94              6.55             5.55
# 394    CDMO           9.41              4.24             3.31
# 1445   NFLX          40.35              5.33             7.36
# 1427   NBIX          64.42              6.95             6.04
# ...     ...            ...               ...              ...
# 2045   TBLT           0.01              0.03             0.41
# 1451   NISN            0.6              0.05             0.06
# 1220   LIZI           1.23              0.06             0.29
# 1028   IMPP           0.32              0.12             0.12
# 2036   TANH           0.46              0.03             0.04
#
#      Enterprise Value/Revenue Enterprise Value/EBITDA   Price  P/E Percentile  \
# 1361                     7.62                   31.75    9.11       99.148211
# 1986                     5.89                   57.97   40.18       94.463373
# 394                      5.29                   97.26    9.44       97.274276
# 1445                     5.49                    8.66  377.60       70.783646
# 1427                     6.27                    40.8  112.50       85.945486
# ...                       ...                     ...     ...             ...
# 2045                      0.1                   -0.52    0.19        0.212947
# 1451                    -0.23                   -2.18    2.39        2.683135
# 1220                    -0.03                    -0.7    3.86        4.429302
# 1028                    -0.29                   -0.59    1.58        1.703578
# 2036                    -0.09                   -0.69    1.35        2.129472
#
#       P/S Percentile  P/B Percentile  EV/R Percentile  EV/EBITDA Percentile  \
# 1361       94.974446       92.419080        96.337308             68.356048
# 1986       92.589438       89.991482        92.206133             81.005111
# 394        83.304940       75.766610        89.224872             99.744463
# 1445       88.756388       96.592845        90.587734             94.207836
# 1427       93.611584       92.759796        93.441227             73.850085
# ...              ...             ...              ...                   ...
# 2045        0.638842        7.155026         8.177172              2.044293
# 1451        1.320273        0.383305         1.277683              7.921635
# 1220        1.703578        4.003407         0.170358              2.896082
# 1028        4.045997        1.405451         1.448041              2.470187
# 2036        0.638842        0.170358         0.724020              2.810903
#
#        RV Score  Number of Shares to Buy
# 1361  90.247019                        0
# 1986  90.051107                        0
# 394   89.063032                        0
# 1445  88.185690                        0
# 1427  87.921635                        0
# ...         ...                      ...
# 2045   3.645656                        0
# 1451   2.717206                        0
# 1220   2.640545                        0
# 1028   2.214651                        0
# 2036   1.294719                        0
#
# [1174 rows x 14 columns]

# %% [markdown]
# ### Defining Portfolio

# %%
def portfolio_input():
    global portfolio_value, number_of_stocks
    portfolio_value = input("Enter the value of your portfolio:")
    number_of_stocks = input("Enter the number of stocks you want to invest in:")

    try:
        value_1 = float(portfolio_value)
        value_2 = float(number_of_stocks)

    except ValueError:
        print("That's not a number! \n Try again:")
        portfolio_value = input("Enter the value of your portfolio:")
        number_of_stocks = input("Enter the number of stocks you want to invest in:")

# %%
portfolio_input()
# Out:
# Enter the value of your portfolio:1000
# Enter the number of stocks you want to invest in:25

# %%
data.sort_values(by = 'RV Score', inplace = True)
portfolio = data[:int(number_of_stocks)]
portfolio.reset_index(drop = True, inplace = True)
portfolio
# Out:
#    Ticker Price/Earnings Price/Sales (TTM) Price/Book (MRQ)  \
# 0    TANH           0.46              0.03             0.04
# 1    IMPP           0.32              0.12             0.12
# 2    LIZI           1.23              0.06             0.29
# 3    NISN            0.6              0.05             0.06
# 4    TBLT           0.01              0.03             0.41
# 5    FAMI            0.1              0.04             0.05
# 6    GSMG           1.06              0.17             0.15
# 7     WGS           1.96              0.26             0.31
# 8    NUWE           0.56              0.13             0.25
# 9    METX           1.33              0.11             0.15
# 10   FOSL            105              0.06              0.3
# 11   CTRM           0.51              0.18             0.09
# 12    PRE           0.36              0.21             0.38
# 13   LDWY           0.75              0.33             0.63
# 14   QIWI           1.19               0.5             0.48
# 15    BON           0.61              0.12             0.13
# 16   RMBL           1.16              0.06             0.55
# 17   RCRT           0.06              0.08             0.96
# 18   ZKIN          11.93              0.21             0.26
# 19   ATXG          1.27k              0.72             0.23
# 20   INPX           0.08              0.08             1.09
# 21   SBFM           1.21              0.47             0.35
# 22    JAN           2.05              0.04             0.13
# 23   CISS           0.35               0.1             0.07
# 24   CLRO           0.93              0.98             0.43
#
#    Enterprise Value/Revenue Enterprise Value/EBITDA  Price  P/E Percentile  \
# 0                     -0.09                   -0.69   1.35        2.129472
# 1                     -0.29                   -0.59   1.58        1.703578
# 2                     -0.03                    -0.7   3.86        4.429302
# 3                     -0.23                   -2.18   2.39        2.683135
# 4                       0.1                   -0.52   0.19        0.212947
# 5                     -0.43                   -9.01   1.60        0.851789
# 6                     -0.74                   -4.56   0.39        3.747871
# 7                      0.05                   -0.03   3.64        6.686542
# 8                     -0.63                    0.73   1.43        2.555366
# 9                      0.04                    0.08   3.55        4.684838
# 10                     0.25                   -20.7   2.06        9.965928
# 11                     0.22                    0.43   0.44        2.470187
# 12                    -0.37                    1.26   0.49        1.873935
# 13                    -0.06                  -29.81   5.35        3.151618
# 14                        0                   -0.02   5.67        4.003407
# 15                      0.3                    1.15   0.40        2.853492
# 16                     0.46                   -2.62   6.13        3.918228
# 17                     0.39                    -0.6   1.21        0.511073
# 18                     0.33                  -13.97   0.70       13.160136
# 19                     -0.6                   -2.32   1.35        4.514480
# 20                      0.4                   -0.22   0.11        0.681431
# 21                    -0.76                    0.41   0.32        4.131175
# 22                     0.04                   -0.73   0.41       36.967632
# 23                     0.54                    1.91   0.46        1.788756
# 24                    -0.03                   -0.02   0.76        3.577513
#
#     P/S Percentile  P/B Percentile  EV/R Percentile  EV/EBITDA Percentile  \
# 0         0.638842        0.170358         0.724020              2.810903
# 1         4.045997        1.405451         1.448041              2.470187
# 2         1.703578        4.003407         0.170358              2.896082
# 3         1.320273        0.383305         1.277683              7.921635
# 4         0.638842        7.155026         8.177172              2.044293
# 5         1.022147        0.255537         1.959114             14.821124
# 6         5.877342        1.959114         2.470187             11.584327
# 7         9.752981        4.557070         6.856899              0.255537
# 8         4.471891        3.321976         2.257240             18.867121
# 9         3.662692        1.959114         6.345826             15.800681
# 10        1.703578        4.216354        11.754685              9.028961
# 11        6.260647        0.809199        10.817717             17.376491
# 12        7.325383        6.345826         1.788756             20.698467
# 13       12.606474       12.350937         0.383305              9.965928
# 14       20.528109        8.645656         5.408859              0.127768
# 15        4.045997        1.660988        12.904600             20.528109
# 16        1.703578       10.817717        17.120954              8.517888
# 17        2.597956       22.657581        15.289608              2.640545
# 18        7.325383        3.407155        13.458262              6.643952
# 19       29.173765        3.109029         2.129472              8.049404
# 20        2.597956       27.385009        15.885860              0.979557
# 21       18.994889        5.706985         2.555366             17.206133
# 22        1.022147        1.660988         6.345826              3.066440
# 23        3.321976        0.553663        20.954003             22.487223
# 24       37.947189        7.964225         0.170358              0.127768
#
#     RV Score  Number of Shares to Buy
# 0   1.294719                       74
# 1   2.214651                       63
# 2   2.640545                       25
# 3   2.717206                       41
# 4   3.645656                      526
# 5   3.781942                       62
# 6   5.127768                      256
# 7   5.621806                       27
# 8   6.294719                       69
# 9   6.490630                 11267605
# 10  7.333901                 19417475
# 11  7.546848                 90909090
# 12  7.606474                 81632653
# 13  7.691652                  7476635
# 14  7.742760                  7054673
# 15  8.398637                100000000
# 16  8.415673                  6525285
# 17  8.739353                 33057851
# 18  8.798978                 57142857
# 19  9.395230                 29629629
# 20  9.505963                363636363
# 21  9.718910                125000000
# 22  9.812606                 97560975
# 23  9.821124                 86956521
# 24  9.957411               1315789473

# %%
position_size = float(portfolio_value) / int(number_of_stocks)

for i in range(0, len(portfolio['Ticker'])):
    portfolio.loc[i, 'Number of Shares to Buy'] = math.floor(position_size / portfolio['Price'][i])
portfolio
# Out:
#    Ticker Price/Earnings Price/Sales (TTM) Price/Book (MRQ)  \
# 0    TANH           0.46              0.03             0.04
# 1    IMPP           0.32              0.12             0.12
# 2    LIZI           1.23              0.06             0.29
# 3    NISN            0.6              0.05             0.06
# 4    TBLT           0.01              0.03             0.41
# 5    FAMI            0.1              0.04             0.05
# 6    GSMG           1.06              0.17             0.15
# 7     WGS           1.96              0.26             0.31
# 8    NUWE           0.56              0.13             0.25
# 9    METX           1.33              0.11             0.15
# 10   FOSL            105              0.06              0.3
# 11   CTRM           0.51              0.18             0.09
# 12    PRE           0.36              0.21             0.38
# 13   LDWY           0.75              0.33             0.63
# 14   QIWI           1.19               0.5             0.48
# 15    BON           0.61              0.12             0.13
# 16   RMBL           1.16              0.06             0.55
# 17   RCRT           0.06              0.08             0.96
# 18   ZKIN          11.93              0.21             0.26
# 19   ATXG          1.27k              0.72             0.23
# 20   INPX           0.08              0.08             1.09
# 21   SBFM           1.21              0.47             0.35
# 22    JAN           2.05              0.04             0.13
# 23   CISS           0.35               0.1             0.07
# 24   CLRO           0.93              0.98             0.43
#
#    Enterprise Value/Revenue Enterprise Value/EBITDA  Price  P/E Percentile  \
# 0                     -0.09                   -0.69   1.35        2.129472
# 1                     -0.29                   -0.59   1.58        1.703578
# 2                     -0.03                    -0.7   3.86        4.429302
# 3                     -0.23                   -2.18   2.39        2.683135
# 4                       0.1                   -0.52   0.19        0.212947
# 5                     -0.43                   -9.01   1.60        0.851789
# 6                     -0.74                   -4.56   0.39        3.747871
# 7                      0.05                   -0.03   3.64        6.686542
# 8                     -0.63                    0.73   1.43        2.555366
# 9                      0.04                    0.08   3.55        4.684838
# 10                     0.25                   -20.7   2.06        9.965928
# 11                     0.22                    0.43   0.44        2.470187
# 12                    -0.37                    1.26   0.49        1.873935
# 13                    -0.06                  -29.81   5.35        3.151618
# 14                        0                   -0.02   5.67        4.003407
# 15                      0.3                    1.15   0.40        2.853492
# 16                     0.46                   -2.62   6.13        3.918228
# 17                     0.39                    -0.6   1.21        0.511073
# 18                     0.33                  -13.97   0.70       13.160136
# 19                     -0.6                   -2.32   1.35        4.514480
# 20                      0.4                   -0.22   0.11        0.681431
# 21                    -0.76                    0.41   0.32        4.131175
# 22                     0.04                   -0.73   0.41       36.967632
# 23                     0.54                    1.91   0.46        1.788756
# 24                    -0.03                   -0.02   0.76        3.577513
#
#     P/S Percentile  P/B Percentile  EV/R Percentile  EV/EBITDA Percentile  \
# 0         0.638842        0.170358         0.724020              2.810903
# 1         4.045997        1.405451         1.448041              2.470187
# 2         1.703578        4.003407         0.170358              2.896082
# 3         1.320273        0.383305         1.277683              7.921635
# 4         0.638842        7.155026         8.177172              2.044293
# 5         1.022147        0.255537         1.959114             14.821124
# 6         5.877342        1.959114         2.470187             11.584327
# 7         9.752981        4.557070         6.856899              0.255537
# 8         4.471891        3.321976         2.257240             18.867121
# 9         3.662692        1.959114         6.345826             15.800681
# 10        1.703578        4.216354        11.754685              9.028961
# 11        6.260647        0.809199        10.817717             17.376491
# 12        7.325383        6.345826         1.788756             20.698467
# 13       12.606474       12.350937         0.383305              9.965928
# 14       20.528109        8.645656         5.408859              0.127768
# 15        4.045997        1.660988        12.904600             20.528109
# 16        1.703578       10.817717        17.120954              8.517888
# 17        2.597956       22.657581        15.289608              2.640545
# 18        7.325383        3.407155        13.458262              6.643952
# 19       29.173765        3.109029         2.129472              8.049404
# 20        2.597956       27.385009        15.885860              0.979557
# 21       18.994889        5.706985         2.555366             17.206133
# 22        1.022147        1.660988         6.345826              3.066440
# 23        3.321976        0.553663        20.954003             22.487223
# 24       37.947189        7.964225         0.170358              0.127768
#
#     RV Score  Number of Shares to Buy
# 0   1.294719                     29.0
# 1   2.214651                     25.0
# 2   2.640545                     10.0
# 3   2.717206                     16.0
# 4   3.645656                    210.0
# 5   3.781942                     25.0
# 6   5.127768                    102.0
# 7   5.621806                     10.0
# 8   6.294719                     27.0
# 9   6.490630                     11.0
# 10  7.333901                     19.0
# 11  7.546848                     90.0
# 12  7.606474                     81.0
# 13  7.691652                      7.0
# 14  7.742760                      7.0
# 15  8.398637                    100.0
# 16  8.415673                      6.0
# 17  8.739353                     33.0
# 18  8.798978                     57.0
# 19  9.395230                     29.0
# 20  9.505963                    363.0
# 21  9.718910                    125.0
# 22  9.812606                     97.0
# 23  9.821124                     86.0
# 24  9.957411                     52.0

# %% [markdown]
# ### Exporting Output to Excel File

# %%
values = {"Ticker": portfolio["Ticker"], "Price": portfolio["Price"], "Number of Shares to Buy": portfolio["Number of Shares to Buy"]}
final_data = pd.DataFrame(data = values)
final_data.to_excel("Value_Strategy.xlsx", sheet_name='Value Strategy', index = False)
